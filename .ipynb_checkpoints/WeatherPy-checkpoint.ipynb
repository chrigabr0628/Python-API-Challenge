# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import CSV
output_data_file = "output_data/cities.csv"

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 593

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = f"https://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units=imperial&q="

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + city

    # print(city_url)
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # print(city_weather)

        # # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']

        # print(city_lat)
        
        city_lng = city_weather['coord']['lon']

        # print(city_lng)
        
        city_max_temp = city_weather['main']['temp_max']

        # print(city_max_temp)
        
        city_humidity = city_weather['main']['humidity']

        # print(city_humidity)
        
        city_clouds = city_weather['clouds']['all']

        # print(city_clouds)
        
        city_wind = city_weather['wind']['speed']

        # print(city_wind)
        
        city_country = city_weather['sys']['country']

        # print(city_country)
        
        city_date = city_weather['dt']

        # print(city_date)

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | grytviken
# Processing Record 2 of Set 1 | palmer
# Processing Record 3 of Set 1 | rongelap
# Processing Record 4 of Set 1 | tromso
# Processing Record 5 of Set 1 | kisangani
# Processing Record 6 of Set 1 | san jose del guaviare
# Processing Record 7 of Set 1 | kailua-kona
# Processing Record 8 of Set 1 | edinburgh of the seven seas
# Processing Record 9 of Set 1 | port elizabeth
# Processing Record 10 of Set 1 | taulaga
# Processing Record 11 of Set 1 | olonkinbyen
# Processing Record 12 of Set 1 | santa ana de yacuma
# Processing Record 13 of Set 1 | am timan
# Processing Record 14 of Set 1 | dom pedro
# Processing Record 15 of Set 1 | waitangi
# Processing Record 16 of Set 1 | punta arenas
# Processing Record 17 of Set 1 | lihue
# Processing Record 18 of Set 1 | iqaluit
# Processing Record 19 of Set 1 | chonchi
# Processing Record 20 of Set 1 | adamstown
# Processing Record 21 of Set 1 | stanley
# Processing Record 22 of Set 1 | hammerfest
# Processing Record 23 of Set 1 | mount pearl
# Processing Record 24 of Set 1 | port-aux-francais
# Processing Record 25 of Set 1 | isafjordur
# Processing Record 26 of Set 1 | puerto ayora
# Processing Record 27 of Set 1 | ushuaia
# Processing Record 28 of Set 1 | tres arroyos
# Processing Record 29 of Set 1 | raduzhnyy
# Processing Record 30 of Set 1 | ciudad insurgentes
# Processing Record 31 of Set 1 | minas de marcona
# Processing Record 32 of Set 1 | hadibu
# Processing Record 33 of Set 1 | enewetak
# Processing Record 34 of Set 1 | dzhalagash
# Processing Record 35 of Set 1 | namibe
# Processing Record 36 of Set 1 | yangor
# City not found. Skipping...
# Processing Record 37 of Set 1 | puerto natales
# Processing Record 38 of Set 1 | norilsk
# Processing Record 39 of Set 1 | jamestown
# Processing Record 40 of Set 1 | saint-pierre
# Processing Record 41 of Set 1 | as sulayyil
# Processing Record 42 of Set 1 | baruun-urt
# Processing Record 43 of Set 1 | waingapu
# Processing Record 44 of Set 1 | minbu
# Processing Record 45 of Set 1 | calvi
# Processing Record 46 of Set 1 | kargasok
# Processing Record 47 of Set 1 | yarmouth
# Processing Record 48 of Set 1 | itoman
# Processing Record 49 of Set 1 | ribeira grande
# Processing Record 50 of Set 1 | zhaozhou
# Processing Record 0 of Set 2 | papao
# Processing Record 1 of Set 2 | longyearbyen
# Processing Record 2 of Set 2 | palma di montechiaro
# Processing Record 3 of Set 2 | flying fish cove
# Processing Record 4 of Set 2 | weinan
# Processing Record 5 of Set 2 | zhezqazghan
# Processing Record 6 of Set 2 | novokayakent
# Processing Record 7 of Set 2 | nicoya
# Processing Record 8 of Set 2 | jardim
# Processing Record 9 of Set 2 | hamilton
# Processing Record 10 of Set 2 | paramonga
# Processing Record 11 of Set 2 | west island
# Processing Record 38 of Set 3 | nova sintra
# Processing Record 39 of Set 3 | hawaiian paradise park
# Processing Record 40 of Set 3 | axim
# Processing Record 41 of Set 3 | tiksi
# Processing Record 42 of Set 3 | baiti
# Processing Record 43 of Set 3 | shanwei
# Processing Record 44 of Set 3 | wanning
# Processing Record 45 of Set 3 | bull savanna
# Processing Record 46 of Set 3 | alofi
# Processing Record 47 of Set 3 | weno
# Processing Record 48 of Set 3 | bamboo flat
# Processing Record 49 of Set 3 | porto real do colegio
# Processing Record 0 of Set 4 | petropavlovsk-kamchatsky
# Processing Record 1 of Set 4 | gumdag
# Processing Record 2 of Set 4 | beira
# Processing Record 3 of Set 4 | kapa'a
# Processing Record 4 of Set 4 | copala
# Processing Record 5 of Set 4 | turpan
# Processing Record 6 of Set 4 | hibbing
# Processing Record 7 of Set 4 | sainte-marie
# Processing Record 8 of Set 4 | awjilah
# Processing Record 9 of Set 4 | arraial do cabo
# Processing Record 10 of Set 4 | cedeira
# Processing Record 11 of Set 4 | xilin hot
# Processing Record 12 of Set 4 | nishinoomote
# Processing Record 13 of Set 4 | mazatlan
# Processing Record 14 of Set 4 | qui nhon
# Processing Record 15 of Set 4 | kirakira
# Processing Record 16 of Set 4 | ilkal
# Processing Record 17 of Set 4 | kruisfontein
# Processing Record 18 of Set 4 | hannibal
# Processing Record 19 of Set 4 | ebon
# Processing Record 20 of Set 4 | bilibino
# Processing Record 21 of Set 4 | mallawi
# Processing Record 22 of Set 4 | bernay
# Processing Record 23 of Set 4 | midvagur
# Processing Record 24 of Set 4 | bilgi
# Processing Record 25 of Set 4 | kuta
# Processing Record 26 of Set 4 | yigo village
# Processing Record 27 of Set 4 | kilindoni
# Processing Record 28 of Set 4 | new norfolk
# Processing Record 29 of Set 4 | la passe
# Processing Record 30 of Set 4 | tomatlan
# Processing Record 31 of Set 4 | albany
# Processing Record 32 of Set 4 | turaif
# Processing Record 33 of Set 4 | mossel bay
# Processing Record 34 of Set 4 | wilmington
# Processing Record 35 of Set 4 | san carlos del zulia
# Processing Record 36 of Set 4 | shahrud
# Processing Record 37 of Set 4 | coos bay
# Processing Record 38 of Set 4 | revda
# Processing Record 39 of Set 4 | novo aripuana
# Processing Record 40 of Set 4 | talnakh
# Processing Record 41 of Set 4 | buala
# Processing Record 42 of Set 4 | san pedro pochutla
# Processing Record 43 of Set 4 | anadyr
# Processing Record 44 of Set 4 | fort bragg
# Processing Record 45 of Set 4 | comandante fontana
# Processing Record 46 of Set 4 | zaltan
# Processing Record 47 of Set 4 | seogwipo
# City not found. Skipping...
# Processing Record 48 of Set 4 | tchintabaraden
# Processing Record 49 of Set 4 | akom ii
# Processing Record 0 of Set 5 | port lincoln
# Processing Record 1 of Set 5 | kuressaare
# Processing Record 2 of Set 5 | geraldton
# Processing Record 3 of Set 5 | hotan
# Processing Record 4 of Set 5 | zalingei
# Processing Record 5 of Set 5 | thompson
# Processing Record 6 of Set 5 | nyagan
# Processing Record 7 of Set 5 | georgetown
# Processing Record 8 of Set 5 | mokhsogollokh
# Processing Record 9 of Set 5 | cidreira
# Processing Record 10 of Set 5 | gulf shores
# Processing Record 11 of Set 5 | port macquarie
# Processing Record 12 of Set 5 | 'ohonua
# City not found. Skipping...
# Processing Record 13 of Set 5 | floro
# Processing Record 14 of Set 5 | fuvahmulah
# City not found. Skipping...
# Processing Record 15 of Set 5 | san antonio del estrecho
# City not found. Skipping...
# Processing Record 16 of Set 5 | dunedin
# Processing Record 17 of Set 5 | gaspe
# Processing Record 18 of Set 5 | the bottom
# Processing Record 19 of Set 5 | aripuana
# Processing Record 20 of Set 5 | laojunmiao
# Processing Record 21 of Set 5 | lodwar
# Processing Record 22 of Set 5 | anisoc
# Processing Record 23 of Set 5 | nazarabad
# Processing Record 24 of Set 5 | antsiranana
# Processing Record 25 of Set 5 | tvoroyri
# Processing Record 26 of Set 5 | botosani
# Processing Record 27 of Set 5 | konarka
# Processing Record 28 of Set 5 | westport
# Processing Record 29 of Set 5 | al jawf
# Processing Record 30 of Set 5 | port saint john's
# Processing Record 31 of Set 5 | la carolina
# Processing Record 32 of Set 5 | gadzhiyevo
# Processing Record 33 of Set 5 | freeport
# Processing Record 34 of Set 5 | brezina
# Processing Record 35 of Set 5 | noyabrsk
# Processing Record 36 of Set 5 | luderitz
# Processing Record 37 of Set 5 | sonsorol village
# City not found. Skipping...
# Processing Record 38 of Set 5 | saint croix
# Processing Record 39 of Set 5 | lago da pedra
# Processing Record 40 of Set 5 | tazovsky
# Processing Record 41 of Set 5 | meiganga
# Processing Record 42 of Set 5 | colonia
# Processing Record 43 of Set 5 | afaahiti
# Processing Record 44 of Set 5 | norrtalje
# Processing Record 45 of Set 5 | vorgashor
# Processing Record 46 of Set 5 | levuka
# Processing Record 47 of Set 5 | tsiombe
# Processing Record 48 of Set 5 | tranovaho
# City not found. Skipping...
# Processing Record 49 of Set 5 | chibougamau
# Processing Record 0 of Set 6 | puerto escondido
# Processing Record 1 of Set 6 | alesund
# Processing Record 2 of Set 6 | lagoa
# Processing Record 3 of Set 6 | morondava
# Processing Record 4 of Set 6 | alipur
# Processing Record 5 of Set 6 | sao joao da barra
# Processing Record 6 of Set 6 | whitehorse
# Processing Record 7 of Set 6 | vadso
# Processing Record 8 of Set 6 | shangzhi
# Processing Record 9 of Set 6 | whyalla stuart
# City not found. Skipping...
# Processing Record 10 of Set 6 | phibun mangsahan
# Processing Record 11 of Set 6 | pudozh
# Processing Record 12 of Set 6 | cockburn town
# Processing Record 13 of Set 6 | kuanda
# Processing Record 14 of Set 6 | nagqu
# Processing Record 15 of Set 6 | myronivka
# Processing Record 16 of Set 6 | tanjung selor
# City not found. Skipping...
# Processing Record 17 of Set 6 | mcminnville
# Processing Record 18 of Set 6 | coquimbo
# Processing Record 19 of Set 6 | shuangcheng
# Processing Record 20 of Set 6 | yaring
# Processing Record 21 of Set 6 | buta
# Processing Record 22 of Set 6 | puerto baquerizo moreno
# Processing Record 23 of Set 6 | saint-paul
# Processing Record 24 of Set 6 | devizes
# Processing Record 25 of Set 6 | saipan
# Processing Record 26 of Set 6 | saint-joseph
# Processing Record 27 of Set 6 | iskateley
# Processing Record 28 of Set 6 | tlahualilo de zaragoza
# Processing Record 29 of Set 6 | broome
# Processing Record 30 of Set 6 | arteche
# Processing Record 31 of Set 6 | iquique
# Processing Record 32 of Set 6 | mukalla
# Processing Record 33 of Set 6 | murghob
# Processing Record 34 of Set 6 | kulia village
# City not found. Skipping...
# Processing Record 35 of Set 6 | remire-montjoly
# Processing Record 36 of Set 6 | ola
# Processing Record 37 of Set 6 | soroa
# Processing Record 38 of Set 6 | vorkuta
# Processing Record 39 of Set 6 | canico
# Processing Record 40 of Set 6 | tarawa
# Processing Record 41 of Set 6 | numaligarh
# Processing Record 42 of Set 6 | quellon
# Processing Record 43 of Set 6 | 'ibri
# City not found. Skipping...
# Processing Record 44 of Set 6 | boda
# Processing Record 45 of Set 6 | moramanga
# Processing Record 46 of Set 6 | nantucket
# Processing Record 47 of Set 6 | talne
# City not found. Skipping...
# Processing Record 48 of Set 6 | kotel'nikovo
# Processing Record 49 of Set 6 | tolanaro
# Processing Record 0 of Set 7 | coronel suarez
# Processing Record 1 of Set 7 | bayanhongor
# Processing Record 2 of Set 7 | patong
# Processing Record 3 of Set 7 | hanting
# Processing Record 4 of Set 7 | fale old settlement
# Processing Record 5 of Set 7 | altamont
# Processing Record 6 of Set 7 | illizi
# Processing Record 7 of Set 7 | mermoz boabab
# Processing Record 8 of Set 7 | crucecita
# Processing Record 9 of Set 7 | ifrane
# Processing Record 10 of Set 7 | masallatah
# Processing Record 11 of Set 7 | nkurenkuru
# City not found. Skipping...
# Processing Record 12 of Set 7 | acapulco de juarez
# Processing Record 13 of Set 7 | costa teguise
# City not found. Skipping...
# Processing Record 14 of Set 7 | chul'man
# Processing Record 15 of Set 7 | manggar
# Processing Record 16 of Set 7 | lembar
# City not found. Skipping...
# Processing Record 17 of Set 7 | toliara
# Processing Record 18 of Set 7 | bereznik
# Processing Record 19 of Set 7 | peniche
# Processing Record 20 of Set 7 | yacimiento rio turbio
# Processing Record 21 of Set 7 | san juan de miraflores
# Processing Record 22 of Set 7 | saint-philippe
# Processing Record 23 of Set 7 | xai-xai
# Processing Record 24 of Set 7 | afif
# Processing Record 25 of Set 7 | pacific grove
# Processing Record 26 of Set 7 | taber
# Processing Record 27 of Set 7 | sola
# Processing Record 28 of Set 7 | avarua
# Processing Record 29 of Set 7 | fort st. john
# Processing Record 30 of Set 7 | ataq
# Processing Record 31 of Set 7 | maiduguri
# Processing Record 32 of Set 7 | lospalos
# Processing Record 33 of Set 7 | dauphin
# Processing Record 34 of Set 7 | mulayjah
# Processing Record 35 of Set 7 | bangjun
# Processing Record 36 of Set 7 | undurkhaan
# Processing Record 37 of Set 7 | kiunga
# Processing Record 38 of Set 7 | pierre
# Processing Record 39 of Set 7 | bhavnagar
# Processing Record 40 of Set 7 | san julian
# Processing Record 41 of Set 7 | alotau
# City not found. Skipping...
# Processing Record 42 of Set 7 | pont rouge
# Processing Record 43 of Set 7 | hailar
# Processing Record 44 of Set 7 | mount gambier
# Processing Record 45 of Set 7 | timimoun
# Processing Record 46 of Set 7 | cestos city
# Processing Record 47 of Set 7 | xining
# Processing Record 48 of Set 7 | san patricio
# Processing Record 49 of Set 7 | prado
# Processing Record 0 of Set 8 | hasaki
# Processing Record 1 of Set 8 | sao jose da coroa grande
# Processing Record 2 of Set 8 | hudson
# Processing Record 3 of Set 8 | o rosal
# Processing Record 4 of Set 8 | reyes
# Processing Record 5 of Set 8 | kangding
# Processing Record 31 of Set 9 | concepcion
# Processing Record 32 of Set 9 | richards bay
# Processing Record 33 of Set 9 | china
# Processing Record 34 of Set 9 | pandan
# Processing Record 35 of Set 9 | brockville
# Processing Record 36 of Set 9 | st. john's
# Processing Record 37 of Set 9 | butterworth
# Processing Record 38 of Set 9 | gebeit
# Processing Record 39 of Set 9 | nemuro
# Processing Record 40 of Set 9 | nguigmi
# Processing Record 41 of Set 9 | neston
# Processing Record 42 of Set 9 | vila velha
# Processing Record 43 of Set 9 | siwa oasis
# Processing Record 44 of Set 9 | sitka
# Processing Record 45 of Set 9 | dryden
# Processing Record 46 of Set 9 | fortuna
# Processing Record 47 of Set 9 | jianshui
# Processing Record 48 of Set 9 | nuuk
# Processing Record 49 of Set 9 | lame
# Processing Record 0 of Set 10 | saldanha
# Processing Record 1 of Set 10 | daru
# Processing Record 2 of Set 10 | priladozhskiy
# Processing Record 3 of Set 10 | uliastay
# Processing Record 4 of Set 10 | antalaha
# Processing Record 5 of Set 10 | hamirpur
# Processing Record 6 of Set 10 | broken hill
# Processing Record 7 of Set 10 | celestun
# Processing Record 8 of Set 10 | puerto leguizamo
# Processing Record 9 of Set 10 | labrador city
# Processing Record 10 of Set 10 | esmeraldas
# Processing Record 11 of Set 10 | hithadhoo
# Processing Record 12 of Set 10 | banska stiavnica
# Processing Record 13 of Set 10 | urzhar
# Processing Record 14 of Set 10 | taroa
# Processing Record 15 of Set 10 | moab
# Processing Record 16 of Set 10 | dhidhdhoo
# Processing Record 17 of Set 10 | yagry
# City not found. Skipping...
# Processing Record 18 of Set 10 | port alfred
# Processing Record 19 of Set 10 | bac lieu
# Processing Record 20 of Set 10 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 21 of Set 10 | soio
# Processing Record 22 of Set 10 | morrope
# Processing Record 23 of Set 10 | hagere maryam
# Processing Record 24 of Set 10 | brits
# Processing Record 25 of Set 10 | vilyuchinsk
# Processing Record 26 of Set 10 | agat village
# Processing Record 27 of Set 10 | dudinka
# Processing Record 28 of Set 10 | aasiaat
# Processing Record 29 of Set 10 | northam
# Processing Record 30 of Set 10 | mariental
# Processing Record 31 of Set 10 | srinagar
# Processing Record 32 of Set 10 | magadan
# Processing Record 33 of Set 10 | puerto san carlos
# City not found. Skipping...
# Processing Record 34 of Set 10 | namie
# Processing Record 35 of Set 10 | alo
# Processing Record 36 of Set 10 | ca mau
# Processing Record 37 of Set 10 | belozersk
# Processing Record 38 of Set 10 | solleftea
# Processing Record 39 of Set 10 | caleta de carquin
# Processing Record 40 of Set 10 | sena madureira
# Processing Record 41 of Set 10 | mezhdurechenskiy
# Processing Record 42 of Set 10 | plymouth
# Processing Record 43 of Set 10 | ahau
# City not found. Skipping...
# Processing Record 44 of Set 10 | verkhnyaya sinyachikha
# Processing Record 45 of Set 10 | mandan
# Processing Record 46 of Set 10 | thief river falls
# Processing Record 47 of Set 10 | strezhevoy
# Processing Record 48 of Set 10 | brumado
# Processing Record 49 of Set 10 | tual
# Processing Record 0 of Set 11 | crane
# Processing Record 1 of Set 11 | rio grande
# Processing Record 2 of Set 11 | shingu
# Processing Record 3 of Set 11 | yelizovo
# Processing Record 4 of Set 11 | havre
# Processing Record 5 of Set 11 | praia da vitoria
# Processing Record 6 of Set 11 | acarau
# Processing Record 7 of Set 11 | karoi
# Processing Record 8 of Set 11 | hashtpar
# Processing Record 9 of Set 11 | nema
# Processing Record 10 of Set 11 | al hufuf
# Processing Record 11 of Set 11 | brooks
# Processing Record 12 of Set 11 | carnarvon
# Processing Record 13 of Set 11 | tezu
# Processing Record 14 of Set 11 | queenstown
# Processing Record 15 of Set 11 | nukunonu
# City not found. Skipping...
# Processing Record 16 of Set 11 | college
# Processing Record 17 of Set 11 | tobelo
# Processing Record 18 of Set 11 | siocon
# Processing Record 19 of Set 11 | kamaishi
# Processing Record 20 of Set 11 | moengo
# Processing Record 21 of Set 11 | ahtari
# Processing Record 22 of Set 11 | laguna
# Processing Record 23 of Set 11 | egilsstadir
# Processing Record 24 of Set 11 | polyarnyy
# Processing Record 25 of Set 11 | happy valley-goose bay
# Processing Record 26 of Set 11 | mhamid
# Processing Record 27 of Set 11 | la libertad
# Processing Record 28 of Set 11 | al bawiti
# Processing Record 29 of Set 11 | kasba tadla
# Processing Record 30 of Set 11 | lethem
# Processing Record 31 of Set 11 | ketchikan
# Processing Record 32 of Set 11 | uturoa
# Processing Record 33 of Set 11 | marolambo
# Processing Record 34 of Set 11 | mildura
# Processing Record 35 of Set 11 | opuwo
# Processing Record 36 of Set 11 | igarka
# Processing Record 37 of Set 11 | galesong
# Processing Record 38 of Set 11 | latakia
# Processing Record 39 of Set 11 | kani keli
# Processing Record 40 of Set 11 | mejit
# Processing Record 41 of Set 11 | taghazout
# Processing Record 42 of Set 11 | urangan
# Processing Record 43 of Set 11 | barcelos
# Processing Record 44 of Set 11 | zarzis
# Processing Record 45 of Set 11 | flin flon
# Processing Record 46 of Set 11 | castillos
# Processing Record 47 of Set 11 | terekli-mekteb
# Processing Record 48 of Set 11 | malpica
# Processing Record 49 of Set 11 | constantia
# Processing Record 0 of Set 12 | hami
# Processing Record 1 of Set 12 | tazacorte
# Processing Record 2 of Set 12 | holualoa
# Processing Record 3 of Set 12 | necochea
# Processing Record 4 of Set 12 | zhanibek
# Processing Record 5 of Set 12 | douentza
# Processing Record 6 of Set 12 | mineiros
# Processing Record 7 of Set 12 | wabag
# Processing Record 8 of Set 12 | hayma'
# City not found. Skipping...
# Processing Record 9 of Set 12 | ghadamis
# Processing Record 10 of Set 12 | zomin shaharchasi
# City not found. Skipping...
# Processing Record 11 of Set 12 | omdurman
# Processing Record 12 of Set 12 | tambacounda
# Processing Record 13 of Set 12 | vega de alatorre
# Processing Record 14 of Set 12 | brisas de zicatela
# Processing Record 15 of Set 12 | aguas vermelhas
# Processing Record 16 of Set 12 | mahdia
# Processing Record 17 of Set 12 | felege neway
# Processing Record 18 of Set 12 | el charco
# Processing Record 19 of Set 12 | las heras
# Processing Record 20 of Set 12 | argo
# Processing Record 21 of Set 12 | jerantut
# Processing Record 22 of Set 12 | mogocha
# Processing Record 23 of Set 12 | vernon
# Processing Record 24 of Set 12 | zaozersk
# Processing Record 25 of Set 12 | berezovyy
# Processing Record 26 of Set 12 | pimenta bueno
# Processing Record 27 of Set 12 | thinadhoo
# Processing Record 28 of Set 12 | kavieng
# Processing Record 29 of Set 12 | el eulma
# Processing Record 30 of Set 12 | castelo do piaui
# Processing Record 31 of Set 12 | mount isa
# Processing Record 32 of Set 12 | bad neuenahr-ahrweiler
# Processing Record 33 of Set 12 | smithers
# Processing Record 34 of Set 12 | mianwali
# Processing Record 35 of Set 12 | airway heights
# Processing Record 36 of Set 12 | amga
# Processing Record 37 of Set 12 | kargalinskaya
# Processing Record 38 of Set 12 | paita
# Processing Record 39 of Set 12 | bodaybo
# Processing Record 40 of Set 12 | dera bugti
# Processing Record 41 of Set 12 | puerto aysen
# Processing Record 42 of Set 12 | mareeba
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          568
# Lat           568
# Lng           568
# Max Temp      568
# Humidity      568
# Cloudiness    568
# Wind Speed    568
# Country       568
# Date          568
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  grytviken -54.2811  -36.5092     37.54        96         100        7.16
# 1     palmer  42.1584  -72.3287     62.83        17          40        5.75
# 2   rongelap  11.1635  166.8941     81.30        72         100       19.15
# 3     tromso  69.6496   18.9570     35.62        64           0        9.22
# 4  kisangani   0.5167   25.2000     72.66        95          60        3.98
#
#   Country        Date
# 0      GS  1714163645
# 1      US  1714163589
# 2      MH  1714163645
# 3      NO  1714164347
# 4      CD  1714164348

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[23], line 2
#       1 # Export the City_Data into a csv
# ----> 2 city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:3902, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3891 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3893 formatter = DataFrameFormatter(
#    3894     frame=df,
#    3895     header=header,
#    (...)
#    3899     decimal=decimal,
#    3900 )
# -> 3902 return DataFrameRenderer(formatter).to_csv(
#    3903     path_or_buf,
#    3904     lineterminator=lineterminator,
#    3905     sep=sep,
#    3906     encoding=encoding,
#    3907     errors=errors,
#    3908     compression=compression,
#    3909     quoting=quoting,
#    3910     columns=columns,
#    3911     index_label=index_label,
#    3912     mode=mode,
#    3913     chunksize=chunksize,
#    3914     quotechar=quotechar,
#    3915     date_format=date_format,
#    3916     doublequote=doublequote,
#    3917     escapechar=escapechar,
#    3918     storage_options=storage_options,
#    3919 )
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\format.py:1152, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1131     created_buffer = False
#    1133 csv_formatter = CSVFormatter(
#    1134     path_or_buf=path_or_buf,
#    1135     lineterminator=lineterminator,
#    (...)
#    1150     formatter=self.fmt,
#    1151 )
# -> 1152 csv_formatter.save()
#    1154 if created_buffer:
#    1155     assert isinstance(path_or_buf, StringIO)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\formats\csvs.py:247, in CSVFormatter.save(self)
#     243 """
#     244 Create the writer & save.
#     245 """
#     246 # apply compression and byte/text conversion
# --> 247 with get_handle(
#     248     self.filepath_or_buffer,
#     249     self.mode,
#     250     encoding=self.encoding,
#     251     errors=self.errors,
#     252     compression=self.compression,
#     253     storage_options=self.storage_options,
#     254 ) as handles:
#     255     # Note: self.encoding is irrelevant here
#     256     self.writer = csvlib.writer(
#     257         handles.handle,
#     258         lineterminator=self.lineterminator,
#    (...)
#     263         quotechar=self.quotechar,
#     264     )
#     266     self._save()
#
# File ~\anaconda3\Lib\site-packages\pandas\io\common.py:739, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     737 # Only for write methods
#     738 if "r" not in mode and is_path:
# --> 739     check_parent_directory(str(handle))
#     741 if compression:
#     742     if compression != "zstd":
#     743         # compression libraries do not like an explicit text-mode
#
# File ~\anaconda3\Lib\site-packages\pandas\io\common.py:604, in check_parent_directory(path)
#     602 parent = Path(path).parent
#     603 if not parent.is_dir():
# --> 604     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: 'output_data'

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE

# Display sample data
northern_hemi_df.head()

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE

# Display sample data
southern_hemi_df.head()

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
